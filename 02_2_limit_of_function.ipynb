# %%
import sympy as sp
import spb

x,a = sp.symbols("x a")

# %% [markdown]
# # Example 1

# %%
fx = (sp.sqrt(x**2 + 9) - 3) / x**2
fx
# Out:
# (sqrt(x**2 + 9) - 3)/x**2

# %%
sp.limit(fx,x,0)
# Out:
# 1/6

# %%
imodule = "panel"
options = dict(
    imodule=imodule, use_latex=False, params={
        a: (5, 0.0000001,1),
    },legend=True)
spb.plot(fx, spb.prange(x, -a, a), **options)
# Out:
# BokehModel(combine_events=True, render_bundle={'docs_json': {'68812299-69f1-4489-97e0-a8232b1206ec': {'version…

# %% [markdown]
# # one sided limits

# %%
fx = sp.Piecewise((0,sp.Lt(x,0)),(1,sp.Ge(x,0)))
fx
# Out:
# Piecewise((0, x < 0), (1, True))

# %%
spb.plot_piecewise(fx,(x,-2,2))

# %% [markdown]
# [BUG for one-sided limit](https://github.com/sympy/sympy/issues/23836)

# %%
sp.limit(fx,x,0,"-")
# Out:
# 1

# %%
sp.limit(fx,x,0,"+")
# Out:
# 1

# %%
sp.limit(sp.sin(sp.pi/x),x,0)
# Out:
# AccumBounds(-1, 1)

# %% [markdown]
# # Asymptotes
#
# limit of $f(x)$, as $x$  $a$, is $\infty$
#
# $$\lim_{x \to a} f(x) = \infty$$

# %%
fx = 1/x**2
fx
# Out:
# x**(-2)

# %%
sp.plot(fx,(x,-0.5,0.5),ylim=(0,100))

# %%
sp.limit(fx,x,0)
# Out:
# oo

# %% [markdown]
# # Example 7

# %%
fx = (2*x) / (x-3)
fx
# Out:
# 2*x/(x - 3)

# %%
sp.plot(fx,(x,1,5),ylim=(-100,100))

# %%
sp.limit(fx,x,3,'-')
# Out:
# -oo

# %%
sp.limit(fx,x,3,'+')
# Out:
# oo

# %%
sp.plot(sp.tan(x),ylim=(-50,50))

# %% [markdown]
# # Exercise

# %% [markdown]
# **1. Explain in your own words what is meant by the equation**
#
# $$\lim_{x\rightarrow2}f(x)=5$$
#
# > as $x$ approaches to 2 but not equal to 2 , $f(x)$ go closer to 5
#
# Is it possible for this statement to be true and yet $f(2)=3?$ Explain.
#
# > Yes it possible when the $f$ has hole at (2,5) and $f$ defined to 3

# %% [markdown]
# ## 2 Explain what it means to say that
#
# $$\lim_{x\rightarrow1^{-}}f(x)=3$$
#
# > as we approach 1 from left $f(x)$ goes to 3
#
# and
#
# $$\lim_{x\rightarrow1^{+}}f(x)=7$$
# > as we approach 1 from right $f(x)$ goes to 7
#
# **In this situation is it possible that \(lim_{z\rightarrow1}f(x)\) exists?**
# > limit does not exist because the right and left at that point is different.

# %% [markdown]
# ## 3 Explain the meaning of each of the following
#
# $$(a) \lim_{x\rightarrow-3}f(x)=\infty$$
# > as we approach closer to -3  $f(x)$ goes to $\infty$
#
# $$(b) \lim_{x\rightarrow4^{+}}f(x)=-\infty$$
# > as we approach closer to 4 from right  $f(x)$ goes to $-\infty$

# %% [markdown]
# ## 4 Use the given graph of f to state the value of each quantity, if it exists. If it does not exist, explain why
#
# ![image.png](attachment:image.png)
#
# $(a) \lim_{x\rightarrow2^{-}}f(x)$
# > Ans : 3
#
# $(b) \lim_{x\rightarrow2^{+}}f(x)$
# > Ans : 1
#
# $(c) \lim_{x\rightarrow2}f(x)$
# > Ans : not exist
#
# $(d) f(2)$
# > Ans : 1
#
# $(e) \lim_{x\rightarrow4}f(x)$
# > Ans : 4
#
# $(f) f(4)$
# > Ans : not exist

# %% [markdown]
# ## 5. For the function f whose graph is given, state the value of each quantity, if it exists. If it does not exist, explain why.
#
# ![image.png](attachment:image.png)
#
# (a) $\lim_{x\rightarrow1}f(x)$
# > Ans : 2
#
# (b) $\lim_{x\rightarrow3^{-}}f(x)$
# > Ans : 1
#
# (c) $\lim_{x\rightarrow3^{+}}f(x)$
# > Ans : 4
#
# (d) $\lim_{x\rightarrow3}f(x)$
# > Ans : not exist
#
# (e) $f(3)$
# > Ans : 3

# %% [markdown]
# ## 6 For the function h whose graph is given, state the value of each quantity, if it exists. If it does not exist, explain why.
#
# ![image.png](attachment:image.png)
#
# (a) $ \lim_{x\rightarrow-3^{-}}h(x)$ :
# > Ans :  4
#
# (b) $ \lim_{x\rightarrow-3^{+}}h(x)$ :
# > Ans :  4
#
# (c) $ \lim_{x\rightarrow-3}h(x)$ :
# > Ans :  4
#
# (d) $ h(-3)$ :
# > Ans :  not defined
#
# (e) $ \lim_{x\rightarrow0^{-}}h(x)$ :
# > Ans :  1
#
# (f) $ \lim_{x\rightarrow0^{+}}h(x)$ :
# > Ans :  -1
#
# (g) $ \lim_{x\rightarrow0}h(x)$ :
# > Ans :  not exist
#
# (h) $ h(0)$ :
# > Ans :  1
#
# (i) $ \lim_{x\rightarrow2}h(x)$ :
# > Ans :  2
#
# (j) $ h(2)$ :
# > Ans :  not defined
#
# (k) $ \lim_{x\rightarrow5^{-}}h(x)$ :
# > Ans :  not defined
#
# (l) $ \lim_{x\rightarrow5^{+}}h(x)$ :
# > Ans :  3

# %% [markdown]
# ## 7. For the function  g whose graph is shown, find a number  a that satisfies the given description.
# ![image.png](attachment:image.png)
#
#
# $(a) \lim_{x\to a} g(x) \text{ does not exist but } g(a) \text{ is defined.}$
# > Ans : 4
#
# $(b) \lim_{x\to a} g(x) \text{ exists but } g(a) \text{ is not defined.}$
# > Ans : 5
#
# $(c) \lim_{x\to a^-} g(x) \text{ and } \lim_{x\to a^+} g(x) \text{ both exist but } \lim_{x\to a} g(x) \text{ does not exist.}$
# > Ans : 2
#
# $(d) \lim_{x\to a} g(x) = g(a) \text{ but } \lim_{x\to a^-} g(x) \neq \lim_{x\to a^+} g(x).$
# > Ans : 4

# %% [markdown]
# ## 8  For the function A whose graph is shown, state the following.
# ![image.png](attachment:image.png)
#
# (a) $\lim_{x\rightarrow-3}A(x)$
# > Ans : $\infty$
#
# (b) $\lim_{x\rightarrow2^{-}}A(x)$
# > Ans : $-\infty$
#
# (c) $\lim_{x\rightarrow2^{+}}A(x)$
# > Ans :  $\infty$
#
# (d) $\lim_{x\rightarrow-1}A(x)$
# > Ans : $-\infty$
#
# (e) The equations of the vertical asymptotes
# > Ans : $x = -3 , x = -1 ,x = 2$

# %% [markdown]
# # 9
#
# $9. \text{For the function } f \text{ whose graph is shown, state the following.} $
#
# ![image.png](attachment:image.png)
#
# $(a) \lim_{x\to -7} f(x)$
# > Ans : $-\infty$
#
# $(b) \lim_{x\to -3} f(x)$
# > Ans : $\infty$
#
# $(c) \lim_{x\to 0} f(x)$
# > Ans : $\infty$
#
# $(d) \lim_{x\to 6^-} f(x)$
# > Ans : $-\infty$
#
# $(e) \lim_{x\to 6^+} f(x)$
# > Ans : $\infty$
#
# $(f) \text{The equations of the vertical asymptotes}$
# > Ans : $x =  -7, x = -3,x = 0,x = 6$

# %% [markdown]
# ## 10
#
# $10. \text{A patient receives a 150-mg injection of a drug every 4 hours. The graph shows the amount } f(t) \text{ of the drug in the bloodstream after } t \text{ hours. Find}$
#
# ![image.png](attachment:image.png)
#
# $(a) \lim_{t\rightarrow 12^-} f(t)$
# > Ans : 150 mg
#
# $(b) \lim_{t\rightarrow 12^+} f(t)$
# > Ans : 300 mg
#
# and explain the significance of these one-sided limits.
# > Ans : left hand limit tell us drug level just before injection and
# >       right hand limit tell us drug level after injection

# %% [markdown]
# ## 11
# **11. Sketch the graph of the function and use it to determine the values of a for which lim, f(x) exists.**
#
# $f(x)=\begin{cases}e^{x}&if~x\le0\\ x-1&if~0<x<1\\ \ln~x&if~x\ge1\end{cases}$
# > Ans : lim exist for a $\left(-\infty, 0\right) \cup \left(0, \infty\right)$

# %%
fx = sp.Piecewise(
    (sp.exp(x),x<=0),
    (x-1,sp.And(x >0, x < 1)),
    (sp.ln(x),x>=1)
)
fx
# Out:
# Piecewise((exp(x), x <= 0), (x - 1, x < 1), (log(x), True))

# %%
spb.plot_piecewise(fx,(x,-5,5))

# %%
sp.print_latex(sp.S.Reals - {0})
# Out:
# \left(-\infty, 0\right) \cup \left(0, \infty\right)

# %% [markdown]
# ## 12
# **12. Sketch the graph of the function and use it to determine the values of a for which lim, f(x) exists.**
#
# $f(x)=\begin{cases}\sqrt[3]{x}&if~x\le-1\\ x&if-1<x\le2\\ (x-1)^{2}&if~x>2\end{cases}$
#
# > Ans : for all a in interval $\left(-\infty, 2\right) \cup \left(2, \infty\right)$

# %%
fx = sp.Piecewise(
    (sp.real_root(x,3),x<=-1),
    (x,x<=2),
    ((x-1)**2,x>2)
)
fx
# Out:
# Piecewise((Piecewise((Abs(x)**(1/3)*sign(x), Eq(im(x), 0)), (x**(1/3), True)), x <= -1), (x, x <= 2), ((x - 1)**2, True))

# %%
spb.plot_piecewise(fx,(x,-4,4))

# %%
sp.S.Reals - {2}
# Out:
# Union(Interval.open(-oo, 2), Interval.open(2, oo))

# %%
fx = x * sp.sqrt(1+x**-2)
fx
# Out:
# x*sqrt(1 + x**(-2))

# %% [markdown]
# ## 13
#
# $13-14. \text{Use the graph of the function } f \text{ to state the value of each limit, if it exists. If it does not exist, explain why.} $
#
#
# $f(x)=x\sqrt{1+x^{-2}}$
#
# $(a) \lim_{x\rightarrow0^-}f(x)$
# > Ans : -1
#
# $(b) \lim_{x\rightarrow0^+}f(x)$
# > Ans : 1
#
# $(c) \lim_{x\rightarrow0}f(x)$
# > Ans : not exists

# %%
sp.plot(fx,(x,-2,2))

# %% [markdown]
# ## 14
#
# $f(x)=\frac{e^{1/x}-2}{e^{1/x}+1}$
#
# $(a) \lim_{x\rightarrow0^-}f(x)$
# > Ans : -2
#
# $(b) \lim_{x\rightarrow0^+}f(x)$
# > Ans : 1
#
# $(c) \lim_{x\rightarrow0}f(x)$
# > Ans : not exists

# %%
fx = (sp.exp(1/x) - 2) / (sp.exp(1/x) + 1)
fx
# Out:
# (exp(1/x) - 2)/(exp(1/x) + 1)

# %%
sp.plot(fx)

# %% [markdown]
# ## 19
#
# $\text{Guess the value of the limit (if it exists) by evaluating the function at the given numbers (correct to six decimal places).}$
#
#
#
# $\lim_{x\rightarrow3}\frac{x^{2}-3x}{x^{2}-9},$
#
# $x=3.1,3.05,3.01,3.001,3.0001$
# $2.9, 2.95, 2.99, 2.999, 2.9999$
#
# > ANS : 0.500008333193656

# %%
fx = (x**2 - 3*x) / (x**2 -9)
fx
# Out:
# (x**2 - 3*x)/(x**2 - 9)

# %%
[fx.subs(x,t) for t in [3.1,3.05,3.01,3.001,3.0001,2.9, 2.95, 2.99, 2.999, 2.9999]]
# Out:
# [0.508196721311475,
#  0.504132231404961,
#  0.500831946755406,
#  0.500083319446697,
#  0.500008333193656,
#  0.491525423728812,
#  0.495798319327735,
#  0.499165275459100,
#  0.499916652775377,
#  0.499991666527086]

# %% [markdown]
# ## 20
#
# $\lim_{x\rightarrow-3}\frac{x^{2}-3x}{x^{2}-9},$
#
# $x=-2.5,2.9, -2.95, -2.99, -2.999, -2.9999,$
# $-3.5,3.1,-3.05, -3.01, -3.001, -3.0001$
#
# > Ans : $-\infty$

# %%
[fx.subs(x,t) for t in [-2.5,2.9, -2.95, -2.99, -2.999, -2.9999,-3.5,3.1,-3.05, -3.01, -3.001, -3.0001]]
# Out:
# [-5.00000000000000,
#  0.491525423728812,
#  -59.0000000000001,
#  -299.000000000005,
#  -2999.00000000040,
#  -29998.9999999337,
#  7.00000000000000,
#  0.508196721311475,
#  61.0000000000003,
#  301.000000000008,
#  3001.00000000026,
#  30000.9999999397]

# %% [markdown]
# ## 21
#
# $\lim_{t\rightarrow0}\frac{e^{5t}-1}{t},$
#
# $t=\pm0.5,\pm0.1,\pm0.01,\pm0.001,\pm0.0001$
#
# > Ans : 5.00125020835851

# %%
fx = (sp.exp(5*x) - 1) /x 
fx
# Out:
# (exp(5*x) - 1)/x

# %%
[fx.subs(x,t) for t in [
0.5,
0.1,
0.01,
0.001,
0.0001,
-0.0001,
-0.001,
-0.01,
-0.1,
-0.5,
]]
# Out:
# [22.3649879214069,
#  6.48721270700128,
#  5.12710963760241,
#  5.01252085940096,
#  5.00125020835851,
#  4.99875020830709,
#  4.98752080731768,
#  4.87705754992860,
#  3.93469340287367,
#  1.83583000275220]

# %% [markdown]
# ## 22
#
# $\lim_{h\rightarrow0}\frac{(2+h)^{5}-32}{h},$
#
# $h=\pm0.5,\pm0.1,\pm0.01,\pm0.001,\pm0.0001$
#
# > ANS : 80.0080004001558

# %%
fx = ((2+x)**5 - 32) / x
fx
# Out:
# ((x + 2)**5 - 32)/x

# %%
[fx.subs(x,t) for t in [
0.5,
0.1,
0.01,
0.001,
0.0001,
-0.0001,
-0.001,
-0.01,
-0.1,
-0.5,
]]
# Out:
# [131.312500000000,
#  88.4101000000001,
#  80.8040100099980,
#  80.0800400099888,
#  80.0080004001558,
#  79.9920003999688,
#  79.9200399899931,
#  79.2039900100001,
#  72.3901000000001,
#  48.8125000000000]
